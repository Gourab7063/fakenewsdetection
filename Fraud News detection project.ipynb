# %%
from google.colab import files
import pandas as pd

# %%
import pandas as pd
import numpy as np

# %%
true = pd.read_csv('True.csv')

# %%
fake =pd.read_csv('Fake.csv')

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['label']=1
fake['label']=0

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
news=pd.concat([fake,true],axis=0)

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date  label
# 21412  August 22, 2017       1
# 21413  August 22, 2017       1
# 21414  August 22, 2017       1
# 21415  August 22, 2017       1
# 21416  August 22, 2017       1

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news=news.drop(['title','subject','date'],axis=1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0

# %%
news=news.sample(frac=1) #resuffle it

# %%
news.head()
# Out:
#                                                     text  label
# 14053  GENEVA (Reuters) - The United Nations refugee ...      1
# 20706  The irony in Obama s radical Treasury Secretar...      0
# 5879   Former New York City Mayor Rudy Giuliani had h...      0
# 856    It turns out that Donald Trump was abusing his...      0
# 9914   We ve been reporting on this unbelievable tren...      0

# %%
news.reset_index(inplace=True)

# %%
news.head()
# Out:
#    index                                               text  label
# 0  14053  GENEVA (Reuters) - The United Nations refugee ...      1
# 1  20706  The irony in Obama s radical Treasury Secretar...      0
# 2   5879  Former New York City Mayor Rudy Giuliani had h...      0
# 3    856  It turns out that Donald Trump was abusing his...      0
# 4   9914  We ve been reporting on this unbelievable tren...      0

# %%
news.drop(['index'],axis=1,inplace=True)

# %%
news.head()
# Out:
#                                                 text  label
# 0  GENEVA (Reuters) - The United Nations refugee ...      1
# 1  The irony in Obama s radical Treasury Secretar...      0
# 2  Former New York City Mayor Rudy Giuliani had h...      0
# 3  It turns out that Donald Trump was abusing his...      0
# 4  We ve been reporting on this unbelievable tren...      0

# %%
import re

# %%
def wordopt(text  ):
  #convert into lowercase
  text=text.lower()
  #remove urls
  text=re.sub(r'https?://\S+|www\.\S+','',text)
  # rmove html tags
  text=re.sub(r'<.*?>','',text)
  #remove punctuation
  text=re.sub(r'[^\w\s]','',text)
  # remove digits
  text=re.sub(r'\d','',text)
  # remove extra spaces
  text=re.sub(r'\s+',' ',text)
  #remove newline characters
  text=re.sub(r'\n','',text)
  return text

# %%
news['text']=news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0        geneva reuters the united nations refugee agen...
# 1        the irony in obama s radical treasury secretar...
# 2        former new york city mayor rudy giuliani had h...
# 3        it turns out that donald trump was abusing his...
# 4        we ve been reporting on this unbelievable tren...
#                                ...
# 44893    paris reuters french president emmanuel macron...
# 44894    the more unsavory people donald trump appoints...
# 44895    president trump and first lady melania trump a...
# 44896    washington reuters the us senate banking commi...
# 44897    newark nj reuters in december as the bridgegat...
# Name: text, Length: 44898, dtype: object

# %%
x=news['text']
y=news['label']

# %%
x
# Out:
# 0        geneva reuters the united nations refugee agen...
# 1        the irony in obama s radical treasury secretar...
# 2        former new york city mayor rudy giuliani had h...
# 3        it turns out that donald trump was abusing his...
# 4        we ve been reporting on this unbelievable tren...
#                                ...
# 44893    paris reuters french president emmanuel macron...
# 44894    the more unsavory people donald trump appoints...
# 44895    president trump and first lady melania trump a...
# 44896    washington reuters the us senate banking commi...
# 44897    newark nj reuters in december as the bridgegat...
# Name: text, Length: 44898, dtype: object

# %%
y
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 44893    1
# 44894    0
# 44895    0
# 44896    1
# 44897    1
# Name: label, Length: 44898, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorization=TfidfVectorizer()

# %%
xv_train=vectorization.fit_transform(x_train)

# %%
xv_test=vectorization.transform(x_test)

# %%
xv_train
# Out:
# <31428x175172 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6455665 stored elements in Compressed Sparse Row format>

# %%
xv_test
# Out:
# <13470x175172 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2724967 stored elements in Compressed Sparse Row format>

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR=LogisticRegression()

# %%
LR.fit(xv_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_lr=LR.predict(xv_test)

# %%
LR.score(xv_test,y_test)
# Out:
# 0.9882702301410542

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6958
#            1       0.99      0.99      0.99      6512
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTC = DecisionTreeClassifier()
DTC.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc = DTC.predict(xv_test)

# %%
DTC.score(xv_test,y_test)
# Out:
# 0.9953971789161099

# %%
print(classification_report(y_test,pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6958
#            1       1.00      0.99      1.00      6512
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()
rfc.fit(xv_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predic_rfc = rfc.predict(xv_test)

# %%
rfc.score(xv_test,y_test)
# Out:
# 0.9859688195991091

# %%
print(classification_report(y_test,predic_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      6958
#            1       0.98      0.99      0.99      6512
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(xv_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
pred_gbc=gbc.predict(xv_test)

# %%
gbc.score(xv_test,y_test)
# Out:
# 0.9945805493689681

# %%
print(classification_report(y_test,pred_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      6958
#            1       0.99      1.00      0.99      6512
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
def output_lable(n):
    if n == 0:
        return "It's a Fake News"
    elif n == 1:
        return "It is a genuine News"

# %%
def manual_testing(news):
    testing_news = {"text":[news]}
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(wordopt)
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)
    pred_LR = LR.predict(new_xv_test)
    pred_DTC = DTC.predict(new_xv_test)
    pred_GBC = gbc.predict(new_xv_test)
    pred_RFC = rfc.predict(new_xv_test)
    return print(f"\n\nLR Prediction : {output_lable(pred_LR)} \nGBC Prediction : {output_lable(pred_GBC)} \nDTC Prediction : {output_lable( pred_DTC)} \nRFC Prediction : {output_lable( pred_RFC)}")#.format(output_lable(pred_LR[0]),output_lable(pred_GBC[0]),output_lable(pred_DTC[0]),output_lable(pred_RFC[0]))

# %%
news_article = str(input())
# Out:
# GENEVA (Reuters) - The United Nations refugee agency called for calm on Thursday after receiving reports of force being used to remove refugees and asylum-seekers from a center closed three weeks ago on Manus Island in Papua New Guinea. About fifty asylum seekers departed an Australian-run detention camp in Papua New Guinea on Thursday after police moved into the complex, confiscating food, water and personal belongings from the roughly 310 who remained. [nL8N1NS6KK] We urge both governments to engage in constructive dialogue, to de-escalate the tensions and work on urgent lasting solutions to their plight, the U.N. High Commission for Refugees (UNHCR) said in a statement. It could not confirm that force had been used as it had not been granted full access to the shuttered facility.

# %%
manual_testing(news_article)
# Out:
# LR Prediction : It is a genuine News
# GBC Prediction : It is a genuine News
# DTC Prediction : It is a genuine News
# RFC Prediction : It is a genuine News
